# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Food_detecting\\src'

# %%
f_path = 'C:\kfood'
dir_path = os.path.abspath(f_path) # 경로 

tmp = list()
tmp_test =list()
a_test =list()

for dirpath, dirnames, filenames in os.walk(dir_path):
    tmp_test.append(dirnames)

    for dirname in dirnames:
        tmp.append(dirname)
        a_test.append(dirpath[14:])
        pass

# %%
f_path = 'C:\kfood'
dir_path = os.path.abspath(f_path) # 경로 

tmp = list()
tmp_test =list()
a_test =list()


for dirpath, dirnames, filenames in os.walk(dir_path):
    print(dirnames)
    a_test.append(dirnames)

    for dirname in dirnames:
        print(dirpath[14:])
# Out:
# ['구이', '국', '기타', '김치', '나물', '떡', '만두', '면', '무침', '밥', '볶음', '쌈', '음청류', '장', '장아찌', '적', '전', '전골', '조림', '죽', '찌개', '찜', '탕', '튀김', '한과', '해물', '회']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '더덕구이', '떡갈비', '불고기', '삼겹살', '장어구이', '조개구이', '조기구이', '황태구이', '훈제오리']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['계란국', '떡국_만두국', '무국', '미역국', '북엇국', '시래기국', '육개장', '콩나물국']
#
#
#
#
#
#
#
#
# []
# []
# []
# []
# []
# []
# []
# []
# ['과메기', '양념치킨', '젓갈', '콩자반', '편육', '피자', '후라이드치킨']
#
#
#
#
#
#
#
# []
# []
# []
# []
# []
# []
# []
# ['갓김치', '깍두기', '나박김치', '무생채', '배추김치', '백김치', '부추김치', '열무김치', '오이소박이', '총각김치', '파김치']
#
#
#
#
#
#
#
#
#
#
#
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['가지볶음', '고사리나물', '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음']
#
#
#
#
#
#
# []
# []
# []
# []
# []
# []
# ['경단', '꿀떡', '송편']
#
#
#
# []
# []
# []
# ['만두']
#
# []
# ...

# %%
f_path
# Out:
# 'C:\\kfood'

# %%
dir_path
# Out:
# 'C:\\kfood'

# %%
big_title = tmp_test[0]
len(big_title), big_title
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-350c21b580bd> in <module>
# ----> 1 big_title = tmp_test[0]
#       2 len(big_title), big_title
#
# IndexError: list index out of range

# %%
S_list = list()
t_test = list()
n_path = f_path+f'/{f_path}'
for de_path in big_title:
    dir_path = os.path.abspath(f_path+f'/{de_path}')
    print(dir_path) # 대타이틀

    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(dirpath[9:])# 구이\훈제오리
        t_test.append(dirpath[9:])
        for dirname in dirnames:
#             print(dirname)
            S_list.append(dirname) # 소타이틀
            pass
# Out:
# C:\kfood\구이
# 구이
# 구이\갈비구이
# 구이\갈치구이
# 구이\고등어구이
# 구이\곱창구이
# 구이\닭갈비
# 구이\더덕구이
# 구이\떡갈비
# 구이\불고기
# 구이\삼겹살
# 구이\장어구이
# 구이\조개구이
# 구이\조기구이
# 구이\황태구이
# 구이\훈제오리
# C:\kfood\국
# 국
# 국\계란국
# 국\떡국_만두국
# 국\무국
# 국\미역국
# 국\북엇국
# 국\시래기국
# 국\육개장
# 국\콩나물국
# C:\kfood\기타
# 기타
# 기타\과메기
# 기타\양념치킨
# 기타\젓갈
# 기타\콩자반
# 기타\편육
# 기타\피자
# 기타\후라이드치킨
# C:\kfood\김치
# 김치
# 김치\갓김치
# 김치\깍두기
# 김치\나박김치
# 김치\무생채
# 김치\배추김치
# 김치\백김치
# 김치\부추김치
# 김치\열무김치
# 김치\오이소박이
# 김치\총각김치
# 김치\파김치
# C:\kfood\나물
# 나물
# 나물\가지볶음
# 나물\고사리나물
# 나물\미역줄기볶음
# 나물\숙주나물
# 나물\시금치나물
# 나물\애호박볶음
# C:\kfood\떡
# 떡
# 떡\경단
# 떡\꿀떡
# 떡\송편
# C:\kfood\만두
# 만두
# 만두\만두
# C:\kfood\면
# 면
# 면\라면
# 면\막국수
# 면\물냉면
# 면\비빔냉면
# 면\수제비
# 면\열무국수
# 면\잔치국수
# 면\짜장면
# 면\짬뽕
# 면\쫄면
# 면\칼국수
# 면\콩국수
# C:\kfood\무침
# 무침
# 무침\꽈리고추무침
# 무침\도라지무침
# 무침\도토리묵
# 무침\잡채
# 무침\콩나물무침
# 무침\홍어무침
# 무침\회무침
# C:\kfood\밥
# 밥
# 밥\김밥
# 밥\김치볶음밥
# 밥\누룽지
# 밥\비빔밥
# 밥\새우볶음밥
# 밥\알밥
# 밥\유부초밥
# 밥\잡곡밥
# 밥\주먹밥
# C:\kfood\볶음
# 볶음
# 볶음\감자채볶음
# 볶음\건새우볶음
# 볶음\고추장진미채볶음
# 볶음\두부김치
# 볶음\떡볶이
# 볶음\라볶이
# 볶음\멸치볶음
# 볶음\소세지볶음
# ...

# %%
len(S_list), S_list
# Out:
# (150,
#  ['갈비구이',
#   '갈치구이',
#   '고등어구이',
#   '곱창구이',
#   '닭갈비',
#   '더덕구이',
#   '떡갈비',
#   '불고기',
#   '삼겹살',
#   '장어구이',
#   '조개구이',
#   '조기구이',
#   '황태구이',
#   '훈제오리',
#   '계란국',
#   '떡국_만두국',
#   '무국',
#   '미역국',
#   '북엇국',
#   '시래기국',
#   '육개장',
#   '콩나물국',
#   '과메기',
#   '양념치킨',
#   '젓갈',
#   '콩자반',
#   '편육',
#   '피자',
#   '후라이드치킨',
#   '갓김치',
#   '깍두기',
#   '나박김치',
#   '무생채',
#   '배추김치',
#   '백김치',
#   '부추김치',
#   '열무김치',
#   '오이소박이',
#   '총각김치',
#   '파김치',
#   '가지볶음',
#   '고사리나물',
#   '미역줄기볶음',
#   '숙주나물',
#   '시금치나물',
#   '애호박볶음',
#   '경단',
#   '꿀떡',
#   '송편',
#   '만두',
#   '라면',
#   '막국수',
#   '물냉면',
#   '비빔냉면',
#   '수제비',
#   '열무국수',
#   '잔치국수',
#   '짜장면',
#   '짬뽕',
#   '쫄면',
#   '칼국수',
#   '콩국수',
#   '꽈리고추무침',
#   '도라지무침',
#   '도토리묵',
#   '잡채',
#   '콩나물무침',
#   '홍어무침',
#   '회무침',
#   '김밥',
#   '김치볶음밥',
#   '누룽지',
#   '비빔밥',
#   '새우볶음밥',
#   '알밥',
#   '유부초밥',
#   '잡곡밥',
#   '주먹밥',
#   '감자채볶음',
#   '건새우볶음',
#   '고추장진미채볶음',
#   '두부김치',
#   '떡볶이',
#   '라볶이',
#   '멸치볶음',
# ...

# %%
len(t_test),t_test
# Out:
# (177,
#  ['구이',
#   '구이\\갈비구이',
#   '구이\\갈치구이',
#   '구이\\고등어구이',
#   '구이\\곱창구이',
#   '구이\\닭갈비',
#   '구이\\더덕구이',
#   '구이\\떡갈비',
#   '구이\\불고기',
#   '구이\\삼겹살',
#   '구이\\장어구이',
#   '구이\\조개구이',
#   '구이\\조기구이',
#   '구이\\황태구이',
#   '구이\\훈제오리',
#   '국',
#   '국\\계란국',
#   '국\\떡국_만두국',
#   '국\\무국',
#   '국\\미역국',
#   '국\\북엇국',
#   '국\\시래기국',
#   '국\\육개장',
#   '국\\콩나물국',
#   '기타',
#   '기타\\과메기',
#   '기타\\양념치킨',
#   '기타\\젓갈',
#   '기타\\콩자반',
#   '기타\\편육',
#   '기타\\피자',
#   '기타\\후라이드치킨',
#   '김치',
#   '김치\\갓김치',
#   '김치\\깍두기',
#   '김치\\나박김치',
#   '김치\\무생채',
#   '김치\\배추김치',
#   '김치\\백김치',
#   '김치\\부추김치',
#   '김치\\열무김치',
#   '김치\\오이소박이',
#   '김치\\총각김치',
#   '김치\\파김치',
#   '나물',
#   '나물\\가지볶음',
#   '나물\\고사리나물',
#   '나물\\미역줄기볶음',
#   '나물\\숙주나물',
#   '나물\\시금치나물',
#   '나물\\애호박볶음',
#   '떡',
#   '떡\\경단',
#   '떡\\꿀떡',
#   '떡\\송편',
#   '만두',
#   '만두\\만두',
#   '면',
#   '면\\라면',
#   '면\\막국수',
#   '면\\물냉면',
#   '면\\비빔냉면',
#   '면\\수제비',
#   '면\\열무국수',
#   '면\\잔치국수',
#   '면\\짜장면',
#   '면\\짬뽕',
#   '면\\쫄면',
# ...

# %%
so_title = '소제목-경단'
list_all = '[파일이름]'
i = '대타이틀'
a = dict({'ImgTitle': so_title, 'ImgName': list_all})

# %%
a
# Out:
# {'ImgTitle': '소제목-경단', 'ImgName': '[파일이름]'}

# %%
177-150
# Out:
# 27

# %%
a={}

for num,so_title in enumerate(t_test):
    a[num] = dict({'ImgTitle': so_title, 'ImgName': list_all})

# %%
a

# %%
b={}

for num,so_title in enumerate(t_test):
    b[num] = dict(a)

# %%
b

# %%
print(a_test)

# %%
d_test = list()
for i in a_test:
    print(i, len(i))
    if len(i) == 0 :
        del i
    else:
        d_test.append(i)

# %%
print(d_test)
# Out:
# [['구이', '국', '기타', '김치', '나물', '떡', '만두', '면', '무침', '밥', '볶음', '쌈', '음청류', '장', '장아찌', '적', '전', '전골', '조림', '죽', '찌개', '찜', '탕', '튀김', '한과', '해물', '회'], ['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '더덕구이', '떡갈비', '불고기', '삼겹살', '장어구이', '조개구이', '조기구이', '황태구이', '훈제오리'], ['계란국', '떡국_만두국', '무국', '미역국', '북엇국', '시래기국', '육개장', '콩나물국'], ['과메기', '양념치킨', '젓갈', '콩자반', '편육', '피자', '후라이드치킨'], ['갓김치', '깍두기', '나박김치', '무생채', '배추김치', '백김치', '부추김치', '열무김치', '오이소박이', '총각김치', '파김치'], ['가지볶음', '고사리나물', '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음'], ['경단', '꿀떡', '송편'], ['만두'], ['라면', '막국수', '물냉면', '비빔냉면', '수제비', '열무국수', '잔치국수', '짜장면', '짬뽕', '쫄면', '칼국수', '콩국수'], ['꽈리고추무침', '도라지무침', '도토리묵', '잡채', '콩나물무침', '홍어무침', '회무침'], ['김밥', '김치볶음밥', '누룽지', '비빔밥', '새우볶음밥', '알밥', '유부초밥', '잡곡밥', '주먹밥'], ['감자채볶음', '건새우볶음', '고추장진미채볶음', '두부김치', '떡볶이', '라볶이', '멸치볶음', '소세지볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음'], ['보쌈'], ['수정과', '식혜'], ['간장게장', '양념게장'], ['깻잎장아찌'], ['떡꼬치'], ['감자전', '계란말이', '계란후라이', '김치전', '동그랑땡', '생선전', '파전', '호박전'], ['곱창전골']
# ...

# %%
print(d_test[0])
# Out:
# ['구이', '국', '기타', '김치', '나물', '떡', '만두', '면', '무침', '밥', '볶음', '쌈', '음청류', '장', '장아찌', '적', '전', '전골', '조림', '죽', '찌개', '찜', '탕', '튀김', '한과', '해물', '회']

# %%
print(d_test[1:])
# Out:
# [['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '더덕구이', '떡갈비', '불고기', '삼겹살', '장어구이', '조개구이', '조기구이', '황태구이', '훈제오리'], ['계란국', '떡국_만두국', '무국', '미역국', '북엇국', '시래기국', '육개장', '콩나물국'], ['과메기', '양념치킨', '젓갈', '콩자반', '편육', '피자', '후라이드치킨'], ['갓김치', '깍두기', '나박김치', '무생채', '배추김치', '백김치', '부추김치', '열무김치', '오이소박이', '총각김치', '파김치'], ['가지볶음', '고사리나물', '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음'], ['경단', '꿀떡', '송편'], ['만두'], ['라면', '막국수', '물냉면', '비빔냉면', '수제비', '열무국수', '잔치국수', '짜장면', '짬뽕', '쫄면', '칼국수', '콩국수'], ['꽈리고추무침', '도라지무침', '도토리묵', '잡채', '콩나물무침', '홍어무침', '회무침'], ['김밥', '김치볶음밥', '누룽지', '비빔밥', '새우볶음밥', '알밥', '유부초밥', '잡곡밥', '주먹밥'], ['감자채볶음', '건새우볶음', '고추장진미채볶음', '두부김치', '떡볶이', '라볶이', '멸치볶음', '소세지볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음'], ['보쌈'], ['수정과', '식혜'], ['간장게장', '양념게장'], ['깻잎장아찌'], ['떡꼬치'], ['감자전', '계란말이', '계란후라이', '김치전', '동그랑땡', '생선전', '파전', '호박전'], ['곱창전골'], ['갈치조림', '감자조림', '고등어조림', '꽁치조림', '두부조림', '땅콩조림', '메추리알장조림', '연근조림', '우엉조림', '장조림', '코다리조림'], ['전복죽', '호박죽'], ['김치찌개', '닭계장', '동태찌개', '된장찌개', '순두부찌개'], 
# ...

# %%
t={}
for j in d_test[1:]:
    print(j)
    t['ImgName'] = j
# Out:
# ['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '더덕구이', '떡갈비', '불고기', '삼겹살', '장어구이', '조개구이', '조기구이', '황태구이', '훈제오리']
# ['계란국', '떡국_만두국', '무국', '미역국', '북엇국', '시래기국', '육개장', '콩나물국']
# ['과메기', '양념치킨', '젓갈', '콩자반', '편육', '피자', '후라이드치킨']
# ['갓김치', '깍두기', '나박김치', '무생채', '배추김치', '백김치', '부추김치', '열무김치', '오이소박이', '총각김치', '파김치']
# ['가지볶음', '고사리나물', '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음']
# ['경단', '꿀떡', '송편']
# ['만두']
# ['라면', '막국수', '물냉면', '비빔냉면', '수제비', '열무국수', '잔치국수', '짜장면', '짬뽕', '쫄면', '칼국수', '콩국수']
# ['꽈리고추무침', '도라지무침', '도토리묵', '잡채', '콩나물무침', '홍어무침', '회무침']
# ['김밥', '김치볶음밥', '누룽지', '비빔밥', '새우볶음밥', '알밥', '유부초밥', '잡곡밥', '주먹밥']
# ['감자채볶음', '건새우볶음', '고추장진미채볶음', '두부김치', '떡볶이', '라볶이', '멸치볶음', '소세지볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음']
# ['보쌈']
# ['수정과', '식혜']
# ['간장게장', '양념게장']
# ['깻잎장아찌']
# ['떡꼬치']
# ['감자전', '계란말이', '계란후라이', '김치전', '동그랑땡', '생선전', '파전', '호박전']
# ['곱창전골']
# ['갈치조림', '감자조림', '고등어조림', '꽁치조림', '두부조림', '땅콩조림', '메추리알장조림', '연근조림', '우엉조림', '장조림', '코다리조림']
# ['전복죽', '호박죽']
# ...

# %%
test={}

for i in d_test[0]:
#     print(i)
    for j in d_test[1:]:
        test[i]={'ImgName': j}
#         print(j)

# %%
test
# Out:
# {'구이': {'ImgName': ['물회', '육회']},
#  '국': {'ImgName': ['물회', '육회']},
#  '기타': {'ImgName': ['물회', '육회']},
#  '김치': {'ImgName': ['물회', '육회']},
#  '나물': {'ImgName': ['물회', '육회']},
#  '떡': {'ImgName': ['물회', '육회']},
#  '만두': {'ImgName': ['물회', '육회']},
#  '면': {'ImgName': ['물회', '육회']},
#  '무침': {'ImgName': ['물회', '육회']},
#  '밥': {'ImgName': ['물회', '육회']},
#  '볶음': {'ImgName': ['물회', '육회']},
#  '쌈': {'ImgName': ['물회', '육회']},
#  '음청류': {'ImgName': ['물회', '육회']},
#  '장': {'ImgName': ['물회', '육회']},
#  '장아찌': {'ImgName': ['물회', '육회']},
#  '적': {'ImgName': ['물회', '육회']},
#  '전': {'ImgName': ['물회', '육회']},
#  '전골': {'ImgName': ['물회', '육회']},
#  '조림': {'ImgName': ['물회', '육회']},
#  '죽': {'ImgName': ['물회', '육회']},
#  '찌개': {'ImgName': ['물회', '육회']},
#  '찜': {'ImgName': ['물회', '육회']},
#  '탕': {'ImgName': ['물회', '육회']},
#  '튀김': {'ImgName': ['물회', '육회']},
#  '한과': {'ImgName': ['물회', '육회']},
#  '해물': {'ImgName': ['물회', '육회']},
#  '회': {'ImgName': ['물회', '육회']}}

# %%
test={}
for i in d_test[0]:
#     print(i)
    for j in d_test[1:]:
        a['ImgName'] = j
        print(j)
#     test[i] = a
# Out:
# ['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '더덕구이', '떡갈비', '불고기', '삼겹살', '장어구이', '조개구이', '조기구이', '황태구이', '훈제오리']
# ['계란국', '떡국_만두국', '무국', '미역국', '북엇국', '시래기국', '육개장', '콩나물국']
# ['과메기', '양념치킨', '젓갈', '콩자반', '편육', '피자', '후라이드치킨']
# ['갓김치', '깍두기', '나박김치', '무생채', '배추김치', '백김치', '부추김치', '열무김치', '오이소박이', '총각김치', '파김치']
# ['가지볶음', '고사리나물', '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음']
# ['경단', '꿀떡', '송편']
# ['만두']
# ['라면', '막국수', '물냉면', '비빔냉면', '수제비', '열무국수', '잔치국수', '짜장면', '짬뽕', '쫄면', '칼국수', '콩국수']
# ['꽈리고추무침', '도라지무침', '도토리묵', '잡채', '콩나물무침', '홍어무침', '회무침']
# ['김밥', '김치볶음밥', '누룽지', '비빔밥', '새우볶음밥', '알밥', '유부초밥', '잡곡밥', '주먹밥']
# ['감자채볶음', '건새우볶음', '고추장진미채볶음', '두부김치', '떡볶이', '라볶이', '멸치볶음', '소세지볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음']
# ['보쌈']
# ['수정과', '식혜']
# ['간장게장', '양념게장']
# ['깻잎장아찌']
# ['떡꼬치']
# ['감자전', '계란말이', '계란후라이', '김치전', '동그랑땡', '생선전', '파전', '호박전']
# ['곱창전골']
# ['갈치조림', '감자조림', '고등어조림', '꽁치조림', '두부조림', '땅콩조림', '메추리알장조림', '연근조림', '우엉조림', '장조림', '코다리조림']
# ['전복죽', '호박죽']
# ...

# %%
a={}

for i, j in enumerate(d_test[1:]):
    i = 'ImgName'
    print(i)
    {a[str(i)] =  j}
#     test[i] = {'ImgName': j}
#     a[num] = dict({'ImgTitle': so_title, 'ImgName': list_all})
# Out:
#   File "<ipython-input-108-9e77c10113ec>", line 6
#     {a[str(i)] =  j}
#                ^
# SyntaxError: invalid syntax

# %%
a
# Out:
# {'ImgName': ['물회', '육회']}

# %%
a={}

for num,so_title in enumerate(t_test):
    a[num] = dict({'ImgTitle': so_title, 'ImgName': list_all})

# %% [markdown]
# test=======

# %%
for key,new_key in zip(a, tmp_name):
    print(key, new_key)
#     a[new_key] = a.pop(key)
