# %%
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Desktop\\고등어조림'

# %%
img = Image.open('./\\test.jpg')
img = np.array(img)
img.shape
# Out:
# (490, 700, 3)

# %%
center = np.round(int(img.shape[0]/ 2)), np.round(int(img.shape[1] / 2))

# %%
for i in range(7):
    img[:,i*100] = 0
plt.figure(figsize = (12,12))
plt.imshow(img[:451,100:])

#img[:,center[1]] = 0
#img[center[0],:] = 0
#plt.figure(figsize = (10,10))
#plt.imshow(img)

# %%
# 질문 ?
# 고등어조림이어야 한다.
# 이미지 처리
# 이미지가 뭐야 ?
# 분석해보자
# 1. 학습을 하기 전 최종 전처리 데이터 => array

# %%
# 1. 고등어조림 이미지가 존나 많다
# 2. 고등어조림이 통제된 환경에서 촬영된 이미지가필요하다
