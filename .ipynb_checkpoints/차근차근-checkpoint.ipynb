# %%
import os , glob
import pathlib
import numpy as np
from PIL import Image

import tensorflow as tf
import matplotlib.pyplot as plt
import IPython.display as display

import seaborn as sns      # 시본 - 그래프 

plt.style.use('seaborn')
sns.set(font_scale=2.5)

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'NanumGothic'

# %%
# tensorflow와 tf.keras를 임포트합니다.
import tensorflow as tf 
from tensorflow import keras
print(tf.__version__) # 텐서플로우 버전확인 


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 1.15.0

# %%
os.getcwd()
# Out:
# 'C:\\Food_detecting'

# %%
f_path = 'C:\kfood' # 파일 경로 
dir_path = os.path.abspath(f_path) # 경로 
print(dir_path)
# Out:
# C:\kfood

# %%
data_dir = pathlib.Path(dir_path)
data_dir
# Out:
# WindowsPath('C:/kfood')

# %%
list(data_dir.glob('*/*'))
# Out:
# [WindowsPath('C:/kfood/구이/갈비구이'),
#  WindowsPath('C:/kfood/구이/갈치구이'),
#  WindowsPath('C:/kfood/구이/고등어구이'),
#  WindowsPath('C:/kfood/구이/곱창구이'),
#  WindowsPath('C:/kfood/구이/닭갈비'),
#  WindowsPath('C:/kfood/구이/더덕구이'),
#  WindowsPath('C:/kfood/구이/떡갈비'),
#  WindowsPath('C:/kfood/구이/불고기'),
#  WindowsPath('C:/kfood/구이/삼겹살'),
#  WindowsPath('C:/kfood/구이/장어구이'),
#  WindowsPath('C:/kfood/구이/조개구이'),
#  WindowsPath('C:/kfood/구이/조기구이'),
#  WindowsPath('C:/kfood/구이/황태구이'),
#  WindowsPath('C:/kfood/구이/훈제오리'),
#  WindowsPath('C:/kfood/국/계란국'),
#  WindowsPath('C:/kfood/국/떡국_만두국'),
#  WindowsPath('C:/kfood/국/무국'),
#  WindowsPath('C:/kfood/국/미역국'),
#  WindowsPath('C:/kfood/국/북엇국'),
#  WindowsPath('C:/kfood/국/시래기국'),
#  WindowsPath('C:/kfood/국/육개장'),
#  WindowsPath('C:/kfood/국/콩나물국'),
#  WindowsPath('C:/kfood/기타/과메기'),
#  WindowsPath('C:/kfood/기타/양념치킨'),
#  WindowsPath('C:/kfood/기타/젓갈'),
#  WindowsPath('C:/kfood/기타/콩자반'),
#  WindowsPath('C:/kfood/기타/편육'),
#  WindowsPath('C:/kfood/기타/피자'),
# ...

# %%
type_list = ['.GIF', '.JPEG', '.PNG', '.bmp', '.gif', '.jpeg','.JPG','.png','.jpg']

# %%
type_list
# Out:
# ['.GIF', '.JPEG', '.PNG', '.bmp', '.gif', '.jpeg', '.JPG', '.png', '.jpg']

# %%
# os.walk를 이용한 방식이 젤 간단하고 빠르다.
for root, sub_dirs, files in os.walk(dir_path):
    # 모든 파일에 대해...
    print(root)
#     for fname in files:
#         # 특정 확장자인 경우 (os.path.splitext 함수 좋다)
#         ext = (os.path.splitext(fname)[-1]).lower()
# #         print(ext)
#         if ext in type_list:
#             pass
#         else:
# #             print(fname)
#             os.remove(fname)
# Out:
# C:\kfood
# C:\kfood\구이
# C:\kfood\구이\갈비구이
# C:\kfood\구이\갈치구이
# C:\kfood\구이\고등어구이
# C:\kfood\구이\곱창구이
# C:\kfood\구이\닭갈비
# C:\kfood\구이\더덕구이
# C:\kfood\구이\떡갈비
# C:\kfood\구이\불고기
# C:\kfood\구이\삼겹살
# C:\kfood\구이\장어구이
# C:\kfood\구이\조개구이
# C:\kfood\구이\조기구이
# C:\kfood\구이\황태구이
# C:\kfood\구이\훈제오리
# C:\kfood\국
# C:\kfood\국\계란국
# C:\kfood\국\떡국_만두국
# C:\kfood\국\무국
# C:\kfood\국\미역국
# C:\kfood\국\북엇국
# C:\kfood\국\시래기국
# C:\kfood\국\육개장
# C:\kfood\국\콩나물국
# C:\kfood\기타
# C:\kfood\기타\과메기
# C:\kfood\기타\양념치킨
# C:\kfood\기타\젓갈
# C:\kfood\기타\콩자반
# C:\kfood\기타\편육
# C:\kfood\기타\피자
# C:\kfood\기타\후라이드치킨
# C:\kfood\김치
# C:\kfood\김치\갓김치
# C:\kfood\김치\깍두기
# C:\kfood\김치\나박김치
# C:\kfood\김치\무생채
# C:\kfood\김치\배추김치
# C:\kfood\김치\백김치
# C:\kfood\김치\부추김치
# C:\kfood\김치\열무김치
# C:\kfood\김치\오이소박이
# C:\kfood\김치\총각김치
# C:\kfood\김치\파김치
# C:\kfood\나물
# C:\kfood\나물\가지볶음
# C:\kfood\나물\고사리나물
# C:\kfood\나물\미역줄기볶음
# C:\kfood\나물\숙주나물
# C:\kfood\나물\시금치나물
# C:\kfood\나물\애호박볶음
# C:\kfood\떡
# C:\kfood\떡\경단
# C:\kfood\떡\꿀떡
# C:\kfood\떡\송편
# ...

# %%
for root, sub_dirs, files in os.walk(dir_path):
    # 모든 파일에 대해...
    for fname in files:
        # 특정 확장자인 경우 (os.path.splitext 함수 좋다)
        ext = (os.path.splitext(fname)[-1]).lower()
#         print(ext)
    for i
        if not ext in type_list:
            print(ext)
# Out:
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# .properties
# .csv
# ...

# %%
PATH = os.path.join(os.path.dirname('C:\\kfood\\'),'new')
PATH
# Out:
# 'C:\\kfood\\new'

# %%
train_dir = os.path.join(PATH,'train')
validation_dir = os.path.join(PATH,'validation')

# %%
validation_dir
# Out:
# 'C:\\kfood\\new\\validation'

# %%
class_names = np.array([item.name for item in data_dir.glob('*/*') if item.name != "*/*.jpg"])
class_names
# Out:
# array(['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '더덕구이', '떡갈비', '불고기',
#        '삼겹살', '장어구이', '조개구이', '조기구이', '황태구이', '훈제오리', '계란국', '떡국_만두국',
#        '무국', '미역국', '북엇국', '시래기국', '육개장', '콩나물국', '과메기', '양념치킨', '젓갈',
#        '콩자반', '편육', '피자', '후라이드치킨', '갓김치', '깍두기', '나박김치', '무생채', '배추김치',
#        '백김치', '부추김치', '열무김치', '오이소박이', '총각김치', '파김치', '가지볶음', '고사리나물',
#        '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음', '경단', '꿀떡', '송편', '만두', '라면',
#        '막국수', '물냉면', '비빔냉면', '수제비', '열무국수', '잔치국수', '짜장면', '짬뽕', '쫄면',
#        '칼국수', '콩국수', '꽈리고추무침', '도라지무침', '도토리묵', '잡채', '콩나물무침', '홍어무침',
#        '회무침', '김밥', '김치볶음밥', '누룽지', '비빔밥', '새우볶음밥', '알밥', '유부초밥', '잡곡밥',
#        '주먹밥', '감자채볶음', '건새우볶음', '고추장진미채볶음', '두부김치', '떡볶이', '라볶이', '멸치볶음',
#        '소세지볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음', '보쌈', '수정과', '식혜',
#        '간장게장', '양념게장', '깻잎장아찌', '떡꼬치', '감자전', '계란말이', '계란후라이', '김치전',
#        '동그랑땡', '생선전', '파전', '호박전', '곱창전골', '갈치조림', '감자조림', '고등어조림',
# ...

# %%
class_names.shape
# Out:
# (150,)

# %%
f_path = 'C:\kfood' # 파일 경로 
dir_path = os.path.abspath(f_path) # 경로 
print(dir_path)
# Out:
# C:\kfood

# %%
dir_path
# Out:
# 'C:\\kfood'
