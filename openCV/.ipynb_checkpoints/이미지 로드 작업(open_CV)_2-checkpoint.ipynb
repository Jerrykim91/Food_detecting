# %% [markdown]
# # 이미지 로드 작업

# %%
import os,glob
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import cv2
print(cv2.__version__)
# Out:
# 4.2.0

# %%
#Read image
img = Image.open('C:\\Food_detecting\\data\\test\\떡볶이\\Img_082_0015.jpg')

# %%
# Fetch image pixel data to numpy array
pix = np.array(img)
pix.shape
# Out:
# (747, 1000, 3)

# %%
plt.imshow(pix)

# %%
plt.imshow(pix, cmap='gray') # 아니됩니다....

# %%
src = cv2.imread('Img_082_0015.jpg', cv2.IMREAD_COLOR)
# dst = Scalar(255,255,255)-src
dst = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# %%
#src = cv2.imread('Img_082_0015.jpg', cv2.IMREAD_COLOR)

#dst = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

#cv2.imshow("src", src)
#cv2.imshow("dst", dst)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
height, width, channel = src.shape
print(height, width , channel)
# Out:
# 747 1000 3

# %%
plt.imshow(src)

# %%
plt.imshow(dst)

# %%
img_test = 'Img_082_0020.jpg'

# %%
img_test = 'Img_082_0020.jpg'
# 3 채널, BGR 이미지 사용
src = cv2.imread(img_test, cv2.IMREAD_COLOR)
# 
dst = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# %%
org = cv2.imread(img_test,cv2.IMREAD_UNCHANGED)
plt.imshow(org)

# %%
plt.imshow(src)

# %%
plt.imshow(dst)

# %%
img_test = 'Img_082_0420.jpg'
# 3 채널, BGR 이미지 사용
src = cv2.imread(img_test, cv2.IMREAD_COLOR)
# 
dst = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# %%
org = cv2.imread(img_test,cv2.IMREAD_UNCHANGED)
plt.imshow(org)

# %%
plt.imshow(src)

# %%
plt.imshow(dst)

# %%
import os,glob
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import cv2
print(cv2.__version__)
# Out:
# 4.2.0

# %%
import os, glob
tmp=list()
for i in glob.glob(os.getcwd()+'\\*'):
    j=i.split('\\')[-1]
#     print(j[-1])
    p=j.split('.')
#     print(p)
    if p[-1] == 'jpg':
        tmp.append(j)
        print(j)
        
print('done')
print(tmp)
# Out:
# Img_028_0056.jpg
# Img_028_0070.jpg
# Img_028_0306.jpg
# Img_028_0951.jpg
# Img_028_0988.jpg
# done
# ['Img_028_0056.jpg', 'Img_028_0070.jpg', 'Img_028_0306.jpg', 'Img_028_0951.jpg', 'Img_028_0988.jpg']

# %%
len(tmp)
# Out:
# 5

# %%
plt.figure(figsize=(8, 5))
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
for i in tmp:
    src = cv2.imread(i, cv2.IMREAD_COLOR)
#     plt.subplot(1,2,1)
    plt.imshow(src)
    plt.show()
    print('='*50)
    dst = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
#     plt.subplot(1,2,1)
    plt.imshow(src)
    plt.show()
