# %%
import os
import pandas as pd

# %%
# dir_path = os.path.abspath('kfood') # 경로 

# tmp = list()
# tmp_test =list()

# for _, dirnames, filenames in os.walk(dir_path):

#     tmp_test.append(dirnames)

# %%
dir_path = os.path.abspath('kfood') # 경로 

tmp = list()
tmp_test =list()
a_test =list()

for dirpath, dirnames, filenames in os.walk(dir_path):
    tmp_test.append(dirnames)

    for dirname in dirnames:
        tmp.append(dirname)
        a_test.append(dirpath[14:])
        pass

# %%
big_title = tmp_test[0]
big_title
# Out:
# ['구이',
#  '국',
#  '기타',
#  '김치',
#  '나물',
#  '떡',
#  '만두',
#  '면',
#  '무침',
#  '밥',
#  '볶음',
#  '쌈',
#  '음청류',
#  '장',
#  '장아찌',
#  '적',
#  '전',
#  '전골',
#  '조림',
#  '죽',
#  '찌개',
#  '찜',
#  '탕',
#  '튀김',
#  '한과',
#  '해물',
#  '회']

# %%
tmp,len(tmp)
# Out:
# (['구이',
#   '국',
#   '기타',
#   '김치',
#   '나물',
#   '떡',
#   '만두',
#   '면',
#   '무침',
#   '밥',
#   '볶음',
#   '쌈',
#   '음청류',
#   '장',
#   '장아찌',
#   '적',
#   '전',
#   '전골',
#   '조림',
#   '죽',
#   '찌개',
#   '찜',
#   '탕',
#   '튀김',
#   '한과',
#   '해물',
#   '회',
#   '갈비구이',
#   '갈치구이',
#   '고등어구이',
#   '곱창구이',
#   '닭갈비',
#   '더덕구이',
#   '떡갈비',
#   '불고기',
#   '삼겹살',
#   '장어구이',
#   '조개구이',
#   '조기구이',
#   '황태구이',
#   '훈제오리',
#   '계란국',
#   '떡국_만두국',
#   '무국',
#   '미역국',
#   '북엇국',
#   '시래기국',
#   '육개장',
#   '콩나물국',
#   '과메기',
#   '양념치킨',
#   '젓갈',
#   '콩자반',
#   '편육',
#   '피자',
#   '후라이드치킨',
#   '갓김치',
#   '깍두기',
#   '나박김치',
#   '무생채',
#   '배추김치',
#   '백김치',
#   '부추김치',
#   '열무김치',
#   '오이소박이',
#   '총각김치',
#   '파김치',
#   '가지볶음',
#   '고사리나물',
#   '미역줄기볶음',
#   '숙주나물',
#   '시금치나물',
#   '애호박볶음',
#   '경단',
#   '꿀떡',
#   '송편',
#   '만두',
#   '라면',
#   '막국수',
#   '물냉면',
#   '비빔냉면',
#   '수제비',
#   '열무국수',
#   '잔치국수',
#   '짜장면',
#   '짬뽕',
#   '쫄면',
#   '칼국수',
#   '콩국수',
#   '꽈리고추무침',
#   '도라지무침',
#   '도토리묵',
#   '잡채',
#   '콩나물무침',
#   '홍어무침',
#   '회무침',
#   '김밥',
#   '김치볶음밥',
#   '누룽지',
#   '비빔밥',
#   '새우볶음밥',
#   '알밥',
#   '유부초밥',
#   '잡곡밥',
#   '주먹밥',
#   '감자채볶음',
#   '건새우볶음',
#   '고추장진미채볶음',
#   '두부김치',
#   '떡볶이',
#   '라볶이',
#   '멸치볶음',
#   '소세지볶음',
#   '어묵볶음',
#   '오징어채볶음',
#   '제육볶음',
#   '주꾸미볶음',
#   '보쌈',
#   '수정과',
#   '식혜',
#   '간장게장',
#   '양념게장',
#   '깻잎장아찌',
#   '떡꼬치',
#   '감자전',
#   '계란말이',
#   '계란후라이',
#   '김치전',
#   '동그랑땡',
#   '생선전',
#   '파전',
#   '호박전',
#   '곱창전골',
#   '갈치조림',
#   '감자조림',
#   '고등어조림',
#   '꽁치조림',
#   '두부조림',
#   '땅콩조림',
#   '메추리알장조림',
#   '연근조림',
#   '우엉조림',
#   '장조림',
#   '코다리조림',
#   '전복죽',
#   '호박죽',
#   '김치찌개',
#   '닭계장',
#   '동태찌개',
#   '된장찌개',
#   '순두부찌개',
#   '갈비찜',
#   '계란찜',
#   '김치찜',
#   '꼬막찜',
#   '닭볶음탕',
#   '수육',
#   '순대',
#   '족발',
#   '찜닭',
#   '해물찜',
#   '갈비탕',
#   '감자탕',
#   '곰탕_설렁탕',
#   '매운탕',
#   '삼계탕',
#   '추어탕',
#   '고추튀김',
#   '새우튀김',
#   '오징어튀김',
#   '약과',
#   '약식',
#   '한과',
#   '멍게',
#   '산낙지',
#   '물회',
#   '육회'],
#  177)

# %%
so_title = '소제목-경단'
list_all='[파일이름]'
i = '대타이틀'
a = dict({'ImgTitle': so_title, 'ImgName': list_all})

# %%
big_title
# Out:
# ['구이',
#  '국',
#  '기타',
#  '김치',
#  '나물',
#  '떡',
#  '만두',
#  '면',
#  '무침',
#  '밥',
#  '볶음',
#  '쌈',
#  '음청류',
#  '장',
#  '장아찌',
#  '적',
#  '전',
#  '전골',
#  '조림',
#  '죽',
#  '찌개',
#  '찜',
#  '탕',
#  '튀김',
#  '한과',
#  '해물',
#  '회']

# %%
t_test =list()

for f_path in big_title:
    dir_path = os.path.abspath(f'kfood/{f_path}')
#     print(dir_path)

    for dirpath, dirnames, filenames in os.walk(dir_path):
#         t_test.append(dirnames)
        for dirname in dirnames:
            print(dirname)
            t_test.append(dirname)
            pass
# Out:
# 갈비구이
# 갈치구이
# 고등어구이
# 곱창구이
# 닭갈비
# 더덕구이
# 떡갈비
# 불고기
# 삼겹살
# 장어구이
# 조개구이
# 조기구이
# 황태구이
# 훈제오리
# 계란국
# 떡국_만두국
# 무국
# 미역국
# 북엇국
# 시래기국
# 육개장
# 콩나물국
# 과메기
# 양념치킨
# 젓갈
# 콩자반
# 편육
# 피자
# 후라이드치킨
# 갓김치
# 깍두기
# 나박김치
# 무생채
# 배추김치
# 백김치
# 부추김치
# 열무김치
# 오이소박이
# 총각김치
# 파김치
# 가지볶음
# 고사리나물
# 미역줄기볶음
# 숙주나물
# 시금치나물
# 애호박볶음
# 경단
# 꿀떡
# 송편
# 만두
# 라면
# 막국수
# 물냉면
# 비빔냉면
# 수제비
# 열무국수
# 잔치국수
# 짜장면
# 짬뽕
# 쫄면
# 칼국수
# 콩국수
# 꽈리고추무침
# 도라지무침
# 도토리묵
# 잡채
# 콩나물무침
# 홍어무침
# 회무침
# 김밥
# 김치볶음밥
# 누룽지
# 비빔밥
# 새우볶음밥
# 알밥
# 유부초밥
# 잡곡밥
# 주먹밥
# 감자채볶음
# 건새우볶음
# 고추장진미채볶음
# 두부김치
# 떡볶이
# 라볶이
# 멸치볶음
# 소세지볶음
# 어묵볶음
# 오징어채볶음
# 제육볶음
# 주꾸미볶음
# 보쌈
# 수정과
# 식혜
# 간장게장
# 양념게장
# 깻잎장아찌
# 떡꼬치
# 감자전
# 계란말이
# 계란후라이
# 김치전
# 동그랑땡
# 생선전
# 파전
# 호박전
# 곱창전골
# 갈치조림
# 감자조림
# 고등어조림
# 꽁치조림
# 두부조림
# 땅콩조림
# 메추리알장조림
# 연근조림
# 우엉조림
# 장조림
# 코다리조림
# 전복죽
# 호박죽
# 김치찌개
# 닭계장
# 동태찌개
# 된장찌개
# 순두부찌개
# 갈비찜
# 계란찜
# 김치찜
# 꼬막찜
# 닭볶음탕
# 수육
# 순대
# 족발
# 찜닭
# 해물찜
# 갈비탕
# 감자탕
# 곰탕_설렁탕
# 매운탕
# 삼계탕
# 추어탕
# 고추튀김
# 새우튀김
# 오징어튀김
# 약과
# 약식
# 한과
# 멍게
# 산낙지
# 물회
# 육회

# %%
len(t_test), t_test
# Out:
# (150,
#  ['갈비구이',
#   '갈치구이',
#   '고등어구이',
#   '곱창구이',
#   '닭갈비',
#   '더덕구이',
#   '떡갈비',
#   '불고기',
#   '삼겹살',
#   '장어구이',
#   '조개구이',
#   '조기구이',
#   '황태구이',
#   '훈제오리',
#   '계란국',
#   '떡국_만두국',
#   '무국',
#   '미역국',
#   '북엇국',
#   '시래기국',
#   '육개장',
#   '콩나물국',
#   '과메기',
#   '양념치킨',
#   '젓갈',
#   '콩자반',
#   '편육',
#   '피자',
#   '후라이드치킨',
#   '갓김치',
#   '깍두기',
#   '나박김치',
#   '무생채',
#   '배추김치',
#   '백김치',
#   '부추김치',
#   '열무김치',
#   '오이소박이',
#   '총각김치',
#   '파김치',
#   '가지볶음',
#   '고사리나물',
#   '미역줄기볶음',
#   '숙주나물',
#   '시금치나물',
#   '애호박볶음',
#   '경단',
#   '꿀떡',
#   '송편',
#   '만두',
#   '라면',
#   '막국수',
#   '물냉면',
#   '비빔냉면',
#   '수제비',
#   '열무국수',
#   '잔치국수',
#   '짜장면',
#   '짬뽕',
#   '쫄면',
#   '칼국수',
#   '콩국수',
#   '꽈리고추무침',
#   '도라지무침',
#   '도토리묵',
#   '잡채',
#   '콩나물무침',
#   '홍어무침',
#   '회무침',
#   '김밥',
#   '김치볶음밥',
#   '누룽지',
#   '비빔밥',
#   '새우볶음밥',
#   '알밥',
#   '유부초밥',
#   '잡곡밥',
#   '주먹밥',
#   '감자채볶음',
#   '건새우볶음',
#   '고추장진미채볶음',
#   '두부김치',
#   '떡볶이',
#   '라볶이',
#   '멸치볶음',
#   '소세지볶음',
#   '어묵볶음',
#   '오징어채볶음',
#   '제육볶음',
#   '주꾸미볶음',
#   '보쌈',
#   '수정과',
#   '식혜',
#   '간장게장',
#   '양념게장',
#   '깻잎장아찌',
#   '떡꼬치',
#   '감자전',
#   '계란말이',
#   '계란후라이',
#   '김치전',
#   '동그랑땡',
#   '생선전',
#   '파전',
#   '호박전',
#   '곱창전골',
#   '갈치조림',
#   '감자조림',
#   '고등어조림',
#   '꽁치조림',
#   '두부조림',
#   '땅콩조림',
#   '메추리알장조림',
#   '연근조림',
#   '우엉조림',
#   '장조림',
#   '코다리조림',
#   '전복죽',
#   '호박죽',
#   '김치찌개',
#   '닭계장',
#   '동태찌개',
#   '된장찌개',
#   '순두부찌개',
#   '갈비찜',
#   '계란찜',
#   '김치찜',
#   '꼬막찜',
#   '닭볶음탕',
#   '수육',
#   '순대',
#   '족발',
#   '찜닭',
#   '해물찜',
#   '갈비탕',
#   '감자탕',
#   '곰탕_설렁탕',
#   '매운탕',
#   '삼계탕',
#   '추어탕',
#   '고추튀김',
#   '새우튀김',
#   '오징어튀김',
#   '약과',
#   '약식',
#   '한과',
#   '멍게',
#   '산낙지',
#   '물회',
#   '육회'])

# %%
so_title = '소제목-경단'
list_all='[파일이름]'
i = '대타이틀'
a = dict({'ImgTitle': so_title, 'ImgName': list_all})

# %%
t_test
# Out:
# ['갈비구이',
#  '갈치구이',
#  '고등어구이',
#  '곱창구이',
#  '닭갈비',
#  '더덕구이',
#  '떡갈비',
#  '불고기',
#  '삼겹살',
#  '장어구이',
#  '조개구이',
#  '조기구이',
#  '황태구이',
#  '훈제오리',
#  '계란국',
#  '떡국_만두국',
#  '무국',
#  '미역국',
#  '북엇국',
#  '시래기국',
#  '육개장',
#  '콩나물국',
#  '과메기',
#  '양념치킨',
#  '젓갈',
#  '콩자반',
#  '편육',
#  '피자',
#  '후라이드치킨',
#  '갓김치',
#  '깍두기',
#  '나박김치',
#  '무생채',
#  '배추김치',
#  '백김치',
#  '부추김치',
#  '열무김치',
#  '오이소박이',
#  '총각김치',
#  '파김치',
#  '가지볶음',
#  '고사리나물',
#  '미역줄기볶음',
#  '숙주나물',
#  '시금치나물',
#  '애호박볶음',
#  '경단',
#  '꿀떡',
#  '송편',
#  '만두',
#  '라면',
#  '막국수',
#  '물냉면',
#  '비빔냉면',
#  '수제비',
#  '열무국수',
#  '잔치국수',
#  '짜장면',
#  '짬뽕',
#  '쫄면',
#  '칼국수',
#  '콩국수',
#  '꽈리고추무침',
#  '도라지무침',
#  '도토리묵',
#  '잡채',
#  '콩나물무침',
#  '홍어무침',
#  '회무침',
#  '김밥',
#  '김치볶음밥',
#  '누룽지',
#  '비빔밥',
#  '새우볶음밥',
#  '알밥',
#  '유부초밥',
#  '잡곡밥',
#  '주먹밥',
#  '감자채볶음',
#  '건새우볶음',
#  '고추장진미채볶음',
#  '두부김치',
#  '떡볶이',
#  '라볶이',
#  '멸치볶음',
#  '소세지볶음',
#  '어묵볶음',
#  '오징어채볶음',
#  '제육볶음',
#  '주꾸미볶음',
#  '보쌈',
#  '수정과',
#  '식혜',
#  '간장게장',
#  '양념게장',
#  '깻잎장아찌',
#  '떡꼬치',
#  '감자전',
#  '계란말이',
#  '계란후라이',
#  '김치전',
#  '동그랑땡',
#  '생선전',
#  '파전',
#  '호박전',
#  '곱창전골',
#  '갈치조림',
#  '감자조림',
#  '고등어조림',
#  '꽁치조림',
#  '두부조림',
#  '땅콩조림',
#  '메추리알장조림',
#  '연근조림',
#  '우엉조림',
#  '장조림',
#  '코다리조림',
#  '전복죽',
#  '호박죽',
#  '김치찌개',
#  '닭계장',
#  '동태찌개',
#  '된장찌개',
#  '순두부찌개',
#  '갈비찜',
#  '계란찜',
#  '김치찜',
#  '꼬막찜',
#  '닭볶음탕',
#  '수육',
#  '순대',
#  '족발',
#  '찜닭',
#  '해물찜',
#  '갈비탕',
#  '감자탕',
#  '곰탕_설렁탕',
#  '매운탕',
#  '삼계탕',
#  '추어탕',
#  '고추튀김',
#  '새우튀김',
#  '오징어튀김',
#  '약과',
#  '약식',
#  '한과',
#  '멍게',
#  '산낙지',
#  '물회',
#  '육회']

# %%
177-150
# Out:
# 27

# %%
len(a_test),a_test
# Out:
# (177,
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '구이',
#   '국',
#   '국',
#   '국',
#   '국',
#   '국',
#   '국',
#   '국',
#   '국',
#   '기타',
#   '기타',
#   '기타',
#   '기타',
#   '기타',
#   '기타',
#   '기타',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '김치',
#   '나물',
#   '나물',
#   '나물',
#   '나물',
#   '나물',
#   '나물',
#   '떡',
#   '떡',
#   '떡',
#   '만두',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '면',
#   '무침',
#   '무침',
#   '무침',
#   '무침',
#   '무침',
#   '무침',
#   '무침',
#   '밥',
#   '밥',
#   '밥',
#   '밥',
#   '밥',
#   '밥',
#   '밥',
#   '밥',
#   '밥',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '볶음',
#   '쌈',
#   '음청류',
#   '음청류',
#   '장',
#   '장',
#   '장아찌',
#   '적',
#   '전',
#   '전',
#   '전',
#   '전',
#   '전',
#   '전',
#   '전',
#   '전',
#   '전골',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '조림',
#   '죽',
#   '죽',
#   '찌개',
#   '찌개',
#   '찌개',
#   '찌개',
#   '찌개',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '찜',
#   '탕',
#   '탕',
#   '탕',
#   '탕',
#   '탕',
#   '탕',
#   '튀김',
#   '튀김',
#   '튀김',
#   '한과',
#   '한과',
#   '한과',
#   '해물',
#   '해물',
#   '회',
#   '회'])

# %%
tmp_name = a_test[27:]
tmp_name
# Out:
# ['구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '구이',
#  '국',
#  '국',
#  '국',
#  '국',
#  '국',
#  '국',
#  '국',
#  '국',
#  '기타',
#  '기타',
#  '기타',
#  '기타',
#  '기타',
#  '기타',
#  '기타',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '김치',
#  '나물',
#  '나물',
#  '나물',
#  '나물',
#  '나물',
#  '나물',
#  '떡',
#  '떡',
#  '떡',
#  '만두',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '면',
#  '무침',
#  '무침',
#  '무침',
#  '무침',
#  '무침',
#  '무침',
#  '무침',
#  '밥',
#  '밥',
#  '밥',
#  '밥',
#  '밥',
#  '밥',
#  '밥',
#  '밥',
#  '밥',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '볶음',
#  '쌈',
#  '음청류',
#  '음청류',
#  '장',
#  '장',
#  '장아찌',
#  '적',
#  '전',
#  '전',
#  '전',
#  '전',
#  '전',
#  '전',
#  '전',
#  '전',
#  '전골',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '조림',
#  '죽',
#  '죽',
#  '찌개',
#  '찌개',
#  '찌개',
#  '찌개',
#  '찌개',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '찜',
#  '탕',
#  '탕',
#  '탕',
#  '탕',
#  '탕',
#  '탕',
#  '튀김',
#  '튀김',
#  '튀김',
#  '한과',
#  '한과',
#  '한과',
#  '해물',
#  '해물',
#  '회',
#  '회']

# %%
# dir_path = os.path.abspath('kfood') # 경로 

# a_test =list()

# for dirpath, dirnames, filenames in os.walk(dir_path):

#     for dirname in dirnames:
        
#         a_test.append(dirpath[14:])

# 지우지마

# %%
a={}

for num,so_title in enumerate(t_test):
    a[num] = dict({'ImgTitle': so_title, 'ImgName': list_all})
#     print(num, so_title)
#     for i in range(len(tmp)):
#         dict_s[i]= a

# %%
len(tmp_name)
# Out:
# 150

# %%
for key,new_key in zip(a, tmp_name):
    print(key, new_key)
#     a[new_key] = a.pop(key)
# Out:
# 2 구이
# 3 구이
# 4 구이
# 5 구이
# 6 구이
# 7 구이
# 8 구이
# 9 구이
# 10 구이
# 11 구이
# 12 구이
# 13 구이
# 14 구이
# 15 구이
# 16 국
# 17 국
# 18 국
# 19 국
# 20 국
# 21 국
# 22 국
# 23 국
# 24 기타
# 25 기타
# 26 기타
# 27 기타
# 28 기타
# 29 기타
# 30 기타
# 31 김치
# 32 김치
# 33 김치
# 34 김치
# 35 김치
# 36 김치
# 37 김치
# 38 김치
# 39 김치
# 40 김치
# 41 김치
# 42 나물
# 43 나물
# 44 나물
# 45 나물
# 46 나물
# 47 나물
# 48 떡
# 49 떡
# 50 떡
# 51 만두
# 52 면
# 53 면
# 54 면
# 55 면
# 56 면
# 57 면
# 58 면
# 59 면
# 60 면
# 61 면
# 62 면
# 63 면
# 64 무침
# 65 무침
# 66 무침
# 67 무침
# 68 무침
# 69 무침
# 70 무침
# 71 밥
# 72 밥
# 73 밥
# 74 밥
# 75 밥
# 76 밥
# 77 밥
# 78 밥
# 79 밥
# 80 볶음
# 81 볶음
# 82 볶음
# 83 볶음
# 84 볶음
# 85 볶음
# 86 볶음
# 87 볶음
# 88 볶음
# 89 볶음
# 90 볶음
# 91 볶음
# 92 쌈
# 93 음청류
# 94 음청류
# 95 장
# 96 장
# 97 장아찌
# 98 적
# 99 전
# 100 전
# 101 전
# 102 전
# 103 전
# 104 전
# 105 전
# 106 전
# 107 전골
# 108 조림
# 109 조림
# 110 조림
# 111 조림
# 112 조림
# 113 조림
# 114 조림
# 115 조림
# 116 조림
# 117 조림
# 118 조림
# 119 죽
# 120 죽
# 121 찌개
# 122 찌개
# 123 찌개
# 124 찌개
# 125 찌개
# 126 찜
# 127 찜
# 128 찜
# 129 찜
# 130 찜
# 131 찜
# 132 찜
# 133 찜
# 134 찜
# 135 찜
# 136 탕
# 137 탕
# 138 탕
# 139 탕
# 140 탕
# 141 탕
# 142 튀김
# 143 튀김
# 144 튀김
# 145 한과
# 146 한과
# 147 한과
# 148 해물
# 149 해물
# 구이 회

# %%
a
# Out:
# {0: {'ImgTitle': '갈비구이', 'ImgName': '[파일이름]'},
#  1: {'ImgTitle': '갈치구이', 'ImgName': '[파일이름]'},
#  2: {'ImgTitle': '고등어구이', 'ImgName': '[파일이름]'},
#  3: {'ImgTitle': '곱창구이', 'ImgName': '[파일이름]'},
#  4: {'ImgTitle': '닭갈비', 'ImgName': '[파일이름]'},
#  5: {'ImgTitle': '더덕구이', 'ImgName': '[파일이름]'},
#  6: {'ImgTitle': '떡갈비', 'ImgName': '[파일이름]'},
#  7: {'ImgTitle': '불고기', 'ImgName': '[파일이름]'},
#  8: {'ImgTitle': '삼겹살', 'ImgName': '[파일이름]'},
#  9: {'ImgTitle': '장어구이', 'ImgName': '[파일이름]'},
#  10: {'ImgTitle': '조개구이', 'ImgName': '[파일이름]'},
#  11: {'ImgTitle': '조기구이', 'ImgName': '[파일이름]'},
#  12: {'ImgTitle': '황태구이', 'ImgName': '[파일이름]'},
#  13: {'ImgTitle': '훈제오리', 'ImgName': '[파일이름]'},
#  14: {'ImgTitle': '계란국', 'ImgName': '[파일이름]'},
#  15: {'ImgTitle': '떡국_만두국', 'ImgName': '[파일이름]'},
#  16: {'ImgTitle': '무국', 'ImgName': '[파일이름]'},
#  17: {'ImgTitle': '미역국', 'ImgName': '[파일이름]'},
#  18: {'ImgTitle': '북엇국', 'ImgName': '[파일이름]'},
#  19: {'ImgTitle': '시래기국', 'ImgName': '[파일이름]'},
#  20: {'ImgTitle': '육개장', 'ImgName': '[파일이름]'},
#  21: {'ImgTitle': '콩나물국', 'ImgName': '[파일이름]'},
#  22: {'ImgTitle': '과메기', 'ImgName': '[파일이름]'},
#  23: {'ImgTitle': '양념치킨', 'ImgName': '[파일이름]'},
#  24: {'ImgTitle': '젓갈', 'ImgName': '[파일이름]'},
#  25: {'ImgTitle': '콩자반', 'ImgName': '[파일이름]'},
#  26: {'ImgTitle': '편육', 'ImgName': '[파일이름]'},
#  27: {'ImgTitle': '피자', 'ImgName': '[파일이름]'},
#  28: {'ImgTitle': '후라이드치킨', 'ImgName': '[파일이름]'},
#  29: {'ImgTitle': '갓김치', 'ImgName': '[파일이름]'},
#  30: {'ImgTitle': '깍두기', 'ImgName': '[파일이름]'},
#  31: {'ImgTitle': '나박김치', 'ImgName': '[파일이름]'},
#  32: {'ImgTitle': '무생채', 'ImgName': '[파일이름]'},
#  33: {'ImgTitle': '배추김치', 'ImgName': '[파일이름]'},
#  34: {'ImgTitle': '백김치', 'ImgName': '[파일이름]'},
#  35: {'ImgTitle': '부추김치', 'ImgName': '[파일이름]'},
#  36: {'ImgTitle': '열무김치', 'ImgName': '[파일이름]'},
#  37: {'ImgTitle': '오이소박이', 'ImgName': '[파일이름]'},
#  38: {'ImgTitle': '총각김치', 'ImgName': '[파일이름]'},
#  39: {'ImgTitle': '파김치', 'ImgName': '[파일이름]'},
#  40: {'ImgTitle': '가지볶음', 'ImgName': '[파일이름]'},
#  41: {'ImgTitle': '고사리나물', 'ImgName': '[파일이름]'},
#  42: {'ImgTitle': '미역줄기볶음', 'ImgName': '[파일이름]'},
#  43: {'ImgTitle': '숙주나물', 'ImgName': '[파일이름]'},
#  44: {'ImgTitle': '시금치나물', 'ImgName': '[파일이름]'},
#  45: {'ImgTitle': '애호박볶음', 'ImgName': '[파일이름]'},
#  46: {'ImgTitle': '경단', 'ImgName': '[파일이름]'},
#  47: {'ImgTitle': '꿀떡', 'ImgName': '[파일이름]'},
#  48: {'ImgTitle': '송편', 'ImgName': '[파일이름]'},
#  49: {'ImgTitle': '만두', 'ImgName': '[파일이름]'},
#  50: {'ImgTitle': '라면', 'ImgName': '[파일이름]'},
#  51: {'ImgTitle': '막국수', 'ImgName': '[파일이름]'},
#  52: {'ImgTitle': '물냉면', 'ImgName': '[파일이름]'},
#  53: {'ImgTitle': '비빔냉면', 'ImgName': '[파일이름]'},
#  54: {'ImgTitle': '수제비', 'ImgName': '[파일이름]'},
#  55: {'ImgTitle': '열무국수', 'ImgName': '[파일이름]'},
#  56: {'ImgTitle': '잔치국수', 'ImgName': '[파일이름]'},
#  57: {'ImgTitle': '짜장면', 'ImgName': '[파일이름]'},
#  58: {'ImgTitle': '짬뽕', 'ImgName': '[파일이름]'},
#  59: {'ImgTitle': '쫄면', 'ImgName': '[파일이름]'},
#  60: {'ImgTitle': '칼국수', 'ImgName': '[파일이름]'},
#  61: {'ImgTitle': '콩국수', 'ImgName': '[파일이름]'},
#  62: {'ImgTitle': '꽈리고추무침', 'ImgName': '[파일이름]'},
#  63: {'ImgTitle': '도라지무침', 'ImgName': '[파일이름]'},
#  64: {'ImgTitle': '도토리묵', 'ImgName': '[파일이름]'},
#  65: {'ImgTitle': '잡채', 'ImgName': '[파일이름]'},
#  66: {'ImgTitle': '콩나물무침', 'ImgName': '[파일이름]'},
#  67: {'ImgTitle': '홍어무침', 'ImgName': '[파일이름]'},
#  68: {'ImgTitle': '회무침', 'ImgName': '[파일이름]'},
#  69: {'ImgTitle': '김밥', 'ImgName': '[파일이름]'},
#  70: {'ImgTitle': '김치볶음밥', 'ImgName': '[파일이름]'},
#  71: {'ImgTitle': '누룽지', 'ImgName': '[파일이름]'},
#  72: {'ImgTitle': '비빔밥', 'ImgName': '[파일이름]'},
#  73: {'ImgTitle': '새우볶음밥', 'ImgName': '[파일이름]'},
#  74: {'ImgTitle': '알밥', 'ImgName': '[파일이름]'},
#  75: {'ImgTitle': '유부초밥', 'ImgName': '[파일이름]'},
#  76: {'ImgTitle': '잡곡밥', 'ImgName': '[파일이름]'},
#  77: {'ImgTitle': '주먹밥', 'ImgName': '[파일이름]'},
#  78: {'ImgTitle': '감자채볶음', 'ImgName': '[파일이름]'},
#  79: {'ImgTitle': '건새우볶음', 'ImgName': '[파일이름]'},
#  80: {'ImgTitle': '고추장진미채볶음', 'ImgName': '[파일이름]'},
#  81: {'ImgTitle': '두부김치', 'ImgName': '[파일이름]'},
#  82: {'ImgTitle': '떡볶이', 'ImgName': '[파일이름]'},
#  83: {'ImgTitle': '라볶이', 'ImgName': '[파일이름]'},
#  84: {'ImgTitle': '멸치볶음', 'ImgName': '[파일이름]'},
#  85: {'ImgTitle': '소세지볶음', 'ImgName': '[파일이름]'},
#  86: {'ImgTitle': '어묵볶음', 'ImgName': '[파일이름]'},
#  87: {'ImgTitle': '오징어채볶음', 'ImgName': '[파일이름]'},
#  88: {'ImgTitle': '제육볶음', 'ImgName': '[파일이름]'},
#  89: {'ImgTitle': '주꾸미볶음', 'ImgName': '[파일이름]'},
#  90: {'ImgTitle': '보쌈', 'ImgName': '[파일이름]'},
#  91: {'ImgTitle': '수정과', 'ImgName': '[파일이름]'},
#  92: {'ImgTitle': '식혜', 'ImgName': '[파일이름]'},
#  93: {'ImgTitle': '간장게장', 'ImgName': '[파일이름]'},
#  94: {'ImgTitle': '양념게장', 'ImgName': '[파일이름]'},
#  95: {'ImgTitle': '깻잎장아찌', 'ImgName': '[파일이름]'},
#  96: {'ImgTitle': '떡꼬치', 'ImgName': '[파일이름]'},
#  97: {'ImgTitle': '감자전', 'ImgName': '[파일이름]'},
#  98: {'ImgTitle': '계란말이', 'ImgName': '[파일이름]'},
#  99: {'ImgTitle': '계란후라이', 'ImgName': '[파일이름]'},
#  100: {'ImgTitle': '김치전', 'ImgName': '[파일이름]'},
#  101: {'ImgTitle': '동그랑땡', 'ImgName': '[파일이름]'},
#  102: {'ImgTitle': '생선전', 'ImgName': '[파일이름]'},
#  103: {'ImgTitle': '파전', 'ImgName': '[파일이름]'},
#  104: {'ImgTitle': '호박전', 'ImgName': '[파일이름]'},
#  105: {'ImgTitle': '곱창전골', 'ImgName': '[파일이름]'},
#  106: {'ImgTitle': '갈치조림', 'ImgName': '[파일이름]'},
#  107: {'ImgTitle': '감자조림', 'ImgName': '[파일이름]'},
#  108: {'ImgTitle': '고등어조림', 'ImgName': '[파일이름]'},
#  109: {'ImgTitle': '꽁치조림', 'ImgName': '[파일이름]'},
#  110: {'ImgTitle': '두부조림', 'ImgName': '[파일이름]'},
#  111: {'ImgTitle': '땅콩조림', 'ImgName': '[파일이름]'},
#  112: {'ImgTitle': '메추리알장조림', 'ImgName': '[파일이름]'},
#  113: {'ImgTitle': '연근조림', 'ImgName': '[파일이름]'},
#  114: {'ImgTitle': '우엉조림', 'ImgName': '[파일이름]'},
#  115: {'ImgTitle': '장조림', 'ImgName': '[파일이름]'},
#  116: {'ImgTitle': '코다리조림', 'ImgName': '[파일이름]'},
#  117: {'ImgTitle': '전복죽', 'ImgName': '[파일이름]'},
#  118: {'ImgTitle': '호박죽', 'ImgName': '[파일이름]'},
#  119: {'ImgTitle': '김치찌개', 'ImgName': '[파일이름]'},
#  120: {'ImgTitle': '닭계장', 'ImgName': '[파일이름]'},
#  121: {'ImgTitle': '동태찌개', 'ImgName': '[파일이름]'},
#  122: {'ImgTitle': '된장찌개', 'ImgName': '[파일이름]'},
#  123: {'ImgTitle': '순두부찌개', 'ImgName': '[파일이름]'},
#  124: {'ImgTitle': '갈비찜', 'ImgName': '[파일이름]'},
#  125: {'ImgTitle': '계란찜', 'ImgName': '[파일이름]'},
#  126: {'ImgTitle': '김치찜', 'ImgName': '[파일이름]'},
#  127: {'ImgTitle': '꼬막찜', 'ImgName': '[파일이름]'},
#  128: {'ImgTitle': '닭볶음탕', 'ImgName': '[파일이름]'},
#  129: {'ImgTitle': '수육', 'ImgName': '[파일이름]'},
#  130: {'ImgTitle': '순대', 'ImgName': '[파일이름]'},
#  131: {'ImgTitle': '족발', 'ImgName': '[파일이름]'},
#  132: {'ImgTitle': '찜닭', 'ImgName': '[파일이름]'},
#  133: {'ImgTitle': '해물찜', 'ImgName': '[파일이름]'},
#  134: {'ImgTitle': '갈비탕', 'ImgName': '[파일이름]'},
#  135: {'ImgTitle': '감자탕', 'ImgName': '[파일이름]'},
#  136: {'ImgTitle': '곰탕_설렁탕', 'ImgName': '[파일이름]'},
#  137: {'ImgTitle': '매운탕', 'ImgName': '[파일이름]'},
#  138: {'ImgTitle': '삼계탕', 'ImgName': '[파일이름]'},
#  139: {'ImgTitle': '추어탕', 'ImgName': '[파일이름]'},
#  140: {'ImgTitle': '고추튀김', 'ImgName': '[파일이름]'},
#  141: {'ImgTitle': '새우튀김', 'ImgName': '[파일이름]'},
#  142: {'ImgTitle': '오징어튀김', 'ImgName': '[파일이름]'},
#  143: {'ImgTitle': '약과', 'ImgName': '[파일이름]'},
#  144: {'ImgTitle': '약식', 'ImgName': '[파일이름]'},
#  145: {'ImgTitle': '한과', 'ImgName': '[파일이름]'},
#  146: {'ImgTitle': '멍게', 'ImgName': '[파일이름]'},
#  147: {'ImgTitle': '산낙지', 'ImgName': '[파일이름]'},
#  148: {'ImgTitle': '물회', 'ImgName': '[파일이름]'},
#  149: {'ImgTitle': '육회', 'ImgName': '[파일이름]'}}

# %%
dict_s={}
for i in big_title:
#     print(i)
    for so_title in t_test:
        dict_s[i]= a
    ## 틀림
